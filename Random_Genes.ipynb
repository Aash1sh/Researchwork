# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# need to keep names such that in need not go blank everytime I see them

# %%
# creating a list of genes
# and converting or dividing into names and integers 
# y = Complete_list

Complete_list = []
#j,k = 0,0
for line in open('GSE102475_GASCH_NaCl-scRNAseq_NormData.txt', 'r'):
    lines = [i for i in line.split()]
    Complete_list.append(lines)

#converting values to float
for i in range(1,len(Complete_list)):
    for j in range(1,len(Complete_list[i])):
        Complete_list[i][j] = float(Complete_list[i][j])

# %%
# making a list of TFs ab = TFs_list
TFs_list = ['YBR182C','YCL055W','YCR065W','YCR106W','YDL170W','YDL106C','YDL056W','YDL020C','YDR034C','YDR043C','YDR096W','YDR123C','YDR146C','YDR207C','YDR213W','YDR216W','YDR253C','YDR310C','YDR423C','YDR463W','YEL009C','YER028C','YER040W','YER045C','YER068W','YER109C','YER111C','YER130C','YER169W','YFL052W','YFL031W','YFL021W','YFR034C','YGL254W','YGL237C','YGL209W','YGL166W','YGL073W','YGL071W','YGL035C','YGL013C','YGR044C','YHL027W','YHL009C','YHR006W','YHR084W','YHR124W','YHR177W','YHR178W','YHR206W','YIL131C','YIL101C','YIL036W','YIR018W','YIR023W','YJL110C','YJL103C','YJR060W','YJR094C','YKL185W','YKL112W','YKL109W','YKL062W','YKL038W','YKL032C','YKL015W','YKR034W','YKR099W','YLR014C','YLR098C','YLR131C','YLR176C','YLR228C','YLR256W','YLR266C','YLR451W','YML099C','YML081W','YML076C','YML007W','YMR019W','YMR021C','YMR037C','YMR042W','YMR043W','YMR070W','YMR164C','YMR172W','YMR280C','YNL314W','YNL216W','YNL167C','YNL103W','YNL068C','YNL027W','YOL108C','YOL067C','YOR028C','YOR113W','YOR140W','YOR162C','YOR337W','YOR344C','YOR358W','YOR363C','YPL248C','YPL230W','YPL202C','YPL089C','YPL075W','YPL038W','YPR008W','YPR065W','YPR199C','YAL051W','YBL103C','YBL021C','YBL005W','YBR049C','YBR066C','YBR083W','YJL089W','YJL056C','YSC0015']
TFs_list.sort()
print(len(TFs_list))
# Out:
# 124

# %%
# making a list of all genes pi = Genes_list
Genes_list = [i[0] for i in Complete_list[1:]]
len(Genes_list)
# Out:
# 6789

# %%
# TF's data that is not present in the sc-rnaseq data
for i in range(len(TFs_list)):
    check = True
    for j in range(len(Genes_list)):
        if TFs_list[i] == Genes_list[j]:
            check = True
            break
        else:
            check = False
    if check == False:
        print(TFs_list[i])
# Out:
# YSC0015

# %%
# making a list of non-TFs from given data
# ji = all_nonTFs_list

all_nonTFs_list = []
for j in range(len(Genes_list)):
    check = False
    for k in range(len(TFs_list)):
        if Genes_list[j] == TFs_list[k]:
            check = True
            
            break
    if check == False:
        all_nonTFs_list.append(Genes_list[j])
    
            
print(len(all_nonTFs_list))
# Out:
# 6666

# %%
# selecting Random 300 genes that are not TFs from the list

#Dont use this regularly it might reset the present data of already selected genes


#import random
#bb = random.sample(ji, 300)

# %%
#randomly selected genes list for future bb = NonTFs_list

'YHR028W-A', 'YHR038W', 'YAL065C', 'YDR130C', 'YGR073C', 'YEL010W', 'YBR187W', 'YJL037W', 'YDL177C', 'YKR091W', 'YMR283C', 'YIR020C-B', 'YKR057W', 'YGR029W', 'YKR037C', 'YJL139C', 'YOL128C', 'YPL279C', 'YGR031C-A', 'YJL208C', 'YDR232W', 'YDL213C', 'YIR007W', 'YML047W-A', 'YLR124W', 'YDR277C', 'YBL101C', 'YER024W', 'YFL001W', 'YOR182C', 'YJL023C', 'YLR393W', 'YJL092W', 'YDR279W', 'YOR161W-B', 'YPR002C-A', 'YML061C', 'YLR174W', 'YMR291W', 'YLR243W', 'YDR005C', 'YNL271C', 'YPL271W', 'YJL028W', 'YHR199C', 'YOR329W-A', 'YCL026C-B', 'YLR286C', 'YER072W', 'ERCC-00014', 'YPL252C', 'YPL122C', 'YGR041W', 'YMR316W', 'YNL218W', 'YNL253W', 'YBR121C', 'YIL159W', 'YPL085W', 'YAL068W-A', 'YER088C-A', 'YLR295C', 'YHL026C', 'YCR047W-A', 'YKL045W', 'YPL109C', 'YFR054C', 'YNR029C', 'YKL053W', 'YML095C', 'ERCC-00017', 'YNL111C', 'YGR169C', 'YKL125W', 'YDR435C', 'YMR108W', 'YER015W', 'YDR430C', 'YGR084C', 'YNL234W', 'YLR325C', 'YGR234W', 'YOR318C', 'YMR133W', 'YDL102W', 'YJL171C']

# %%
# plotting distribution of the random genes

li = Complete_list[0][1:]
l = []

for i in range(len(Complete_list)):
    for j in range(len(NonTFs_list)):
        if NonTFs_list[j] == Complete_list[i][0]:
            print(Complete_list[i][0])
            #count = count+1
            l = Complete_list[i][1:]
            pu = 1
            
    
    if len(l) == 0:
        continue
    if pu == 1:
        plt.title(y[i][0])
        plt.xlabel('Cells')
        plt.ylabel('Counts')
        plt.yticks(l)
        plt.plot(li, l)
        #plt.savefig( "/home/aashish/Research/Research_working_on/cells_plots_non_TF/aaa/"+y[i][0]+'.png', dpi=300, bbox_inches='tight')
        plt.show()
    l = []
# Out:
# ERCC-00004
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 6>()
#      16     continue
#      17 if pu == 1:
# ---> 18     plt.title(y[i][0])
#      19     plt.xlabel('Cells')
#      20     plt.ylabel('Counts')
#
# NameError: name 'y' is not defined

# %%
print(NonTFs_list)
# Out:
# ['YJR096W', 'YLR352W', 'YHR186C', 'YGL168W', 'YEL009C-A', 'YGR213C', 'YNL159C', 'YDL215C', 'YDR281C', 'YAR050W', 'YDR095C', 'YHL005C', 'YDL114W', 'YFR035C', 'YER134C', 'YLR041W', 'YNR042W', 'YCL049C', 'YER136W', 'YLR144C', 'YDR287W', 'YOR384W', 'YDL024C', 'YBR293W', 'YPR020W', 'YDR390C', 'YLR151C', 'YDR098C-B', 'YHR089C', 'YNL178W', 'YGR123C', 'YLR111W', 'YNL299W', 'YLR272C', 'YML103C', 'YDR072C', 'YIL091C', 'YLR052W', 'YGR031W', 'YBR296C-A', 'YGL041W-A', 'YNL231C', 'YDR433W', 'YHL048C-A', 'YDR297W', 'YIL153W', 'YOR037W', 'YPL017C', 'YNL259C', 'YDR467C', 'YJR112W', 'YJL008C', 'YNL277W-A', 'YNR001W-A', 'YOR271C', 'YDR411C', 'YDR245W', 'YHR189W', 'YBR062C', 'YOR009W', 'YOR030W', 'YKR048C', 'YDR065W', 'YGL242C', 'YDR140W', 'YNL279W', 'YGR088W', 'YLR399C', 'YPL152W-A', 'YGL203C', 'YDR425W', 'YGR119C', 'YOR073W', 'YDL146W', 'YBR103W', 'YPR002W', 'ERCC-00012', 'YJL132W', 'YNL145W', 'YJR151W-A', 'YKR062W', 'YCR009C', 'YDR388W', 'YBR001C', 'YHR060W', 'YOR220W', 'YDR182W-A', 'YKL012W', 'YCL06
# ...

# %%
li = Complete_list[0][1:]
l = []
count = 0
#print(li)
pu = 0
for i in range(len(Complete_list)):
    for j in range(len(NonTFs_list)):
        if NonTFs_list[j] == Complete_list[i][0]:
            print(Complete_list[i][0])
            count = count+1
            l = Complete_list[i][1:]
            pu = 1
    
    if len(l) == 0:
        continue
    if pu == 1:
        k = []
        for m in range(1,164):
            k.append(m)
            # Creating dataset
        p=[]
        #for n in range(len(l)):
        #    ju = int(l[n]*100)
        #    for j in range(ju):
        #        p.append(n)
        #    a = np.array(p)
        fig, ax = plt.subplots()
        ax.hist(l,bins = 30)
        plt.yscale('log')
        #plt.savefig( '/home/aashish/Research/Research_working_on/cells_plots_non_TF/plots_in_histogram/'+y[i][0]+'.png')
        plt.show()
    l = []
# Out:
# ERCC-00004
# ERCC-00012
# ERCC-00014
# ERCC-00017
# ERCC-00025
# ERCC-00143
# YAL024C
# YAL032C
# YAL065C
# YAL068W-A
# YAR009C
# YAR050W
# YBL010C
# YBL087C
# YBL101C
# YBL113C
# YBR001C
# YBR057C
# YBR062C
# YBR080C
# YBR089C-A
# YBR103W
# YBR121C
# YBR125C
# YBR187W
# YBR191W
# YBR208C
# YBR251W
# YBR257W
# YBR293W
# YBR296C-A
# YCL026C-B
# YCL049C
# YCL051W
# YCL067C
# YCR006C
# YCR009C
# YCR047W-A
# YCR092C
# YDL024C
# YDL062W
# YDL083C
# YDL102W
# YDL114W
# YDL138W
# YDL146W
# YDL177C
# YDL213C
# YDL215C
# YDL241W
# YDR005C
# YDR065W
# YDR067C
# YDR072C
# YDR095C
# YDR098C-B
# YDR130C
# YDR140W
# YDR155C
# YDR162C
# YDR182W-A
# YDR184C
# YDR232W
# YDR239C
# YDR245W
# YDR251W
# YDR277C
# YDR279W
# YDR281C
# YDR287W
# YDR297W
# YDR312W
# YDR347W
# YDR363W-A
# YDR388W
# YDR390C
# YDR411C
# YDR425W
# YDR430C
# YDR433W
# YDR435C
# YDR442W
# YDR467C
# YDR529C
# YEL009C-A
# YEL010W
# YER015W
# YER024W
# YER039C-A
# YER065C
# YER072W
# YER088C-A
# YER096W
# YER134C
# YER136W
# YFL001W
# ...

# %%
def variance(data):
    # Number of observations
    n = len(data)
    # Mean of the data
    mean = sum(data) / n
    # Square deviations
    deviations = [(x - mean) ** 2 for x in data]
    # Variance
    variance = sum(deviations) / n
    return variance,mean

# %%
# creating variance and mean list of TFs, 1 = Tfs

plt.rcParams["figure.figsize"] = (15,11.5)
li = Complete_list[0][1:]
l = []
var1 = []
me1 = []

count = 0
#print(li)
pu = 0
for i in range(len(Complete_list)):
    for j in range(len(TFs_list)):
        if TFs_list[j] == Complete_list[i][0]:
            #print(y[i][0])
            count = count+1
            l = Complete_list[i][1:]
            pu = 1
    
    if len(l) == 0:
        continue
    if pu == 1:
        k = []
        a,b = variance(l)
        # Creating dataset
        var1.append(a)
        me1.append(b)
        #p=[]
        #plt.show()
    l = []

# %%
# creating variance and mean list of non Tfs, 2 = non Tfs

plt.rcParams["figure.figsize"] = (15,11.5)
li = Complete_list[0][1:]
l = []
var2 = []
me2 = []

count = 0
#print(li)
pu = 0
for i in range(len(Complete_list)):
    for j in range(len(NonTFs_list)):
        if NonTFs_list[j] == Complete_list[i][0]:
            #print(y[i][0])
            count = count+1
            l = Complete_list[i][1:]
            pu = 1
    
    if len(l) == 0:
        continue
    if pu == 1:
        k = []
        a,b = variance(l)
        # Creating dataset
        var2.append(a)
        me2.append(b)
        #p=[]
        #plt.show()
    l = []

# %%
# var/mean and var/mean2 for TFS second 1 = Tfs
p11 = []
p21 = []
# here p1 var/mean vs mean
# here p2 is var/mean^2 vs mean

for i in range(len(var1)):
    a,b = 0,0
    if me1[i] == 0:
        a = 0
    else:
        a = var1[i]/me1[i]
        b = var1[i]/(me1[i]*me1[i])
    p11.append(a)
    p21.append(b)

# %%
# var/mean and var/mean2 for non - Tfs second 2 = non-Tfs

p12 = []
p22 = []
# here p1 var/mean vs mean
# here p2 is var/mean^2 vs mean

for i in range(len(var2)):
    a,b = 0,0
    if me2[i] == 0:
        a = 0
    else:
        a = var2[i]/me2[i]
        b = var2[i]/(me2[i]*me2[i])
    p12.append(a)
    p22.append(b)

# %%
# non log scale
#plt.xscale("log")
#plt.yscale("log")
plt.rcParams["figure.figsize"] = (16,12.5)
plt.scatter(me1,var1,s = 40,c='b')
plt.scatter(me2,var2,s = 10 ,c='r')
plt.savefig( '/home/aashish/Research/Research_working_on/varvsmean1.png')
plt.show()

# %%
#non log scale
#plt.xscale("log")
#plt.yscale("log")
plt.rcParams["figure.figsize"] = (16,12.5)
plt.scatter(me1,p11,c='b')
plt.scatter(me2,p12,c='r')
plt.savefig( '/home/aashish/Research/Research_working_on/varbymeanvsmean1.png')
plt.show()

# %%
# non log scale
#plt.xscale("log")
#plt.yscale("log")
plt.rcParams["figure.figsize"] = (16,12.5)
plt.scatter(me1,p21,c='b')
plt.scatter(me2,p22,c='r')
plt.savefig( '/home/aashish/Research/Research_working_on/varbymeansqvsmean1.png')
plt.show()

# %%
# log scale
plt.rcParams["figure.figsize"] = (16,12.5)
plt.xscale("log")
plt.yscale("log")
plt.scatter(me1,var1,c='b')
plt.scatter(me2,var2,c='r')
plt.savefig( '/home/aashish/Research/Research_working_on/varvsmeanlogscale1.png')
plt.show()

# %%
#log scale
plt.rcParams["figure.figsize"] = (16,12.5)
plt.xscale("log")
plt.yscale("log")
plt.scatter(me1,p11,c='b')
plt.scatter(me2,p12,c='r')
plt.savefig( '/home/aashish/Research/Research_working_on/varbymeanvsmeanlogscale1.png')
plt.show()

# %%
# log scale
plt.rcParams["figure.figsize"] = (16,12.5)
plt.xscale("log")
plt.yscale("log")
plt.scatter(me1,p21,c='b')
plt.scatter(me2,p22,c='r')
plt.savefig( '/home/aashish/Research/Research_working_on/varbymeansqvsmeanlogscale1.png')
plt.show()
